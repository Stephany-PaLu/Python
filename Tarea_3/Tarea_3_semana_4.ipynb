# %% [markdown]
# # Nombre: Stephany Lisbeth Pachay Luna

# %% [markdown]
# # Fecha: 17 de Octubre de 2023.

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # 1. Acceder los datos de manera remota.

# %%
datos_partidos= pd.read_csv('https://raw.githubusercontent.com/cienciadedatos/datos-de-miercoles/master/datos/2019/2019-04-10/partidos.txt',delimiter='\t')
datos_partidos
# Out:
#      anio anfitrion                   estadio                  ciudad  \
# 0    1930   Uruguay           Estadio Pocitos              Montevideo
# 1    1930   Uruguay    Estadio Parque Central              Montevideo
# 2    1930   Uruguay    Estadio Parque Central              Montevideo
# 3    1930   Uruguay           Estadio Pocitos              Montevideo
# 4    1930   Uruguay    Estadio Parque Central              Montevideo
# ..    ...       ...                       ...                     ...
# 895  2018     Rusia              Samara Arena          Samara (UTC+4)
# 896  2018     Rusia  Saint Petersburg Stadium  St. Petersburg (UTC+3)
# 897  2018     Rusia          Luzhniki Stadium          Moscow (UTC+3)
# 898  2018     Rusia  Saint Petersburg Stadium  St. Petersburg (UTC+3)
# 899  2018     Rusia          Luzhniki Stadium          Moscow (UTC+3)
#
#     partido_orden       fecha        equipo_1    equipo_2  equipo_1_final  \
# 0             (1)  1930-07-13         Francia      Mexico               4
# 1             (2)  1930-07-13  Estados Unidos     Bélgica               3
# 2             (3)  1930-07-14      Yugoslavia      Brasil               2
# 3             (4)  1930-07-14         Rumania        Perú               3
# 4             (5)  1930-07-15       Argentina     Francia               1
# ..            ...         ...             ...         ...             ...
# 895          (60)  2018-07-07          Suecia  Inglaterra               0
# 896          (61)  2018-07-10         Francia     Bélgica               1
# 897          (62)  2018-07-11         Croacia  Inglaterra               2
# 898          (63)  2018-07-14         Bélgica  Inglaterra               2
# 899          (64)  2018-07-15         Francia     Croacia               4
#
#      equipo_2_final
# 0                 1
# 1                 0
# 2                 1
# 3                 1
# 4                 0
# ..              ...
# 895               2
# 896               0
# 897               1
# 898               0
# 899               2
#
# [900 rows x 10 columns]

# %% [markdown]
# # 2. Crear dos gráficos en el que comparen a al menos dos países diferentes.

# %%
equipos = datos_partidos[(datos_partidos.equipo_1 == 'Ecuador') | (datos_partidos.equipo_1 == 'Argentina') | (datos_partidos.equipo_1 == 'Brasil') | (datos_partidos.equipo_1 == 'Colombia') | (datos_partidos.equipo_1 == 'Uruguay')]
equipos
# Out:
#      anio anfitrion                  estadio                   ciudad  \
# 4    1930   Uruguay   Estadio Parque Central               Montevideo
# 8    1930   Uruguay       Estadio Centenario               Montevideo
# 10   1930   Uruguay       Estadio Centenario               Montevideo
# 11   1930   Uruguay       Estadio Centenario               Montevideo
# 13   1930   Uruguay       Estadio Centenario               Montevideo
# ..    ...       ...                      ...                      ...
# 884  2018     Rusia            Fisht Stadium            Sochi (UTC+3)
# 888  2018     Rusia             Samara Arena           Samara (UTC+4)
# 891  2018     Rusia          Spartak Stadium           Moscow (UTC+3)
# 892  2018     Rusia  Nizhny Novgorod Stadium  Nizhny Novgorod (UTC+3)
# 893  2018     Rusia              Kazan Arena            Kazan (UTC+3)
#
#     partido_orden       fecha   equipo_1    equipo_2  equipo_1_final  \
# 4             (5)  1930-07-15  Argentina     Francia               1
# 8             (9)  1930-07-18    Uruguay        Perú               1
# 10           (11)  1930-07-19  Argentina      Mexico               6
# 11           (12)  1930-07-20     Brasil     Bolivia               4
# 13           (14)  1930-07-21    Uruguay     Rumania               4
# ..            ...         ...        ...         ...             ...
# 884          (49)  2018-06-30    Uruguay    Portugal               2
# 888          (53)  2018-07-02     Brasil      Mexico               2
# 891          (56)  2018-07-03   Colombia  Inglaterra               3
# 892          (57)  2018-07-06    Uruguay     Francia               0
# 893          (58)  2018-07-06     Brasil     Bélgica               1
#
#      equipo_2_final
# 4                 0
# 8                 0
# 10                3
# 11                0
# 13                0
# ..              ...
# 884               1
# 888               0
# 891               4
# 892               2
# 893               2
#
# [176 rows x 10 columns]

# %%
prueba=["anfitrion", "estadio", "ciudad", "partido_orden", "fecha", "equipo_2", "equipo_2_final"]
prueba
# Out:
# ['anfitrion',
#  'estadio',
#  'ciudad',
#  'partido_orden',
#  'fecha',
#  'equipo_2',
#  'equipo_2_final']

# %%
paises = equipos.equipo_1
paises
# Out:
# 4      Argentina
# 8        Uruguay
# 10     Argentina
# 11        Brasil
# 13       Uruguay
#          ...
# 884      Uruguay
# 888       Brasil
# 891     Colombia
# 892      Uruguay
# 893       Brasil
# Name: equipo_1, Length: 176, dtype: object

# %%
equipos = equipos.drop(prueba, axis=1)

# %%
equipos.head()
# Out:
#     anio   equipo_1  equipo_1_final
# 4   1930  Argentina               1
# 8   1930    Uruguay               1
# 10  1930  Argentina               6
# 11  1930     Brasil               4
# 13  1930    Uruguay               4

# %%
equipos = equipos[['equipo_1', 'anio', 'equipo_1_final']]
equipos
# Out:
#       equipo_1  anio  equipo_1_final
# 4    Argentina  1930               1
# 8      Uruguay  1930               1
# 10   Argentina  1930               6
# 11      Brasil  1930               4
# 13     Uruguay  1930               4
# ..         ...   ...             ...
# 884    Uruguay  2018               2
# 888     Brasil  2018               2
# 891   Colombia  2018               3
# 892    Uruguay  2018               0
# 893     Brasil  2018               1
#
# [176 rows x 3 columns]

# %%
equipos_nuevo = equipos.pivot_table(index='anio', columns='equipo_1', values='equipo_1_final', aggfunc='sum')
equipos_nuevo
# Out:
# equipo_1  Argentina  Brasil  Colombia  Ecuador  Uruguay
# anio
# 1930           16.0     4.0       NaN      NaN     15.0
# 1938            NaN     9.0       NaN      NaN      NaN
# 1950            NaN    21.0       NaN      NaN     15.0
# 1954            NaN     8.0       NaN      NaN     14.0
# 1958            3.0     6.0       NaN      NaN      NaN
# 1962            1.0    14.0       NaN      NaN      2.0
# 1966            4.0     2.0       NaN      NaN      2.0
# 1970            NaN     8.0       NaN      NaN      3.0
# 1974            7.0     1.0       NaN      NaN      1.0
# 1978           12.0     4.0       NaN      NaN      NaN
# 1982            7.0    10.0       NaN      NaN      NaN
# 1986           13.0     8.0       NaN      NaN      1.0
# 1990            3.0     4.0       NaN      NaN      0.0
# 1994            6.0    10.0       1.0      NaN      NaN
# 1998           11.0    17.0       1.0      NaN      NaN
# 2002            1.0     9.0       NaN      1.0      1.0
# 2006           10.0     6.0       NaN      3.0      NaN
# 2010            8.0     8.0       NaN      NaN     10.0
# 2014            5.0     9.0       7.0      0.0      3.0
# 2018            1.0     6.0       4.0      NaN      6.0

# %%
equipos_nuevo.columns[equipos_nuevo.columns.str.contains('a')]
# Out:
# Index(['Argentina', 'Brasil', 'Colombia', 'Ecuador', 'Uruguay'], dtype='object', name='equipo_1')

# %%
equipos_nuevo.columns.name = None

# %%
equipos_nuevo.columns[equipos_nuevo.columns.str.contains('a')]
# Out:
# Index(['Argentina', 'Brasil', 'Colombia', 'Ecuador', 'Uruguay'], dtype='object')

# %%
equipos_nuevo
# Out:
#       Argentina  Brasil  Colombia  Ecuador  Uruguay
# anio
# 1930       16.0     4.0       NaN      NaN     15.0
# 1938        NaN     9.0       NaN      NaN      NaN
# 1950        NaN    21.0       NaN      NaN     15.0
# 1954        NaN     8.0       NaN      NaN     14.0
# 1958        3.0     6.0       NaN      NaN      NaN
# 1962        1.0    14.0       NaN      NaN      2.0
# 1966        4.0     2.0       NaN      NaN      2.0
# 1970        NaN     8.0       NaN      NaN      3.0
# 1974        7.0     1.0       NaN      NaN      1.0
# 1978       12.0     4.0       NaN      NaN      NaN
# 1982        7.0    10.0       NaN      NaN      NaN
# 1986       13.0     8.0       NaN      NaN      1.0
# 1990        3.0     4.0       NaN      NaN      0.0
# 1994        6.0    10.0       1.0      NaN      NaN
# 1998       11.0    17.0       1.0      NaN      NaN
# 2002        1.0     9.0       NaN      1.0      1.0
# 2006       10.0     6.0       NaN      3.0      NaN
# 2010        8.0     8.0       NaN      NaN     10.0
# 2014        5.0     9.0       7.0      0.0      3.0
# 2018        1.0     6.0       4.0      NaN      6.0

# %%
equipos_nuevo.index
# Out:
# Index([1930, 1938, 1950, 1954, 1958, 1962, 1966, 1970, 1974, 1978, 1982, 1986,
#        1990, 1994, 1998, 2002, 2006, 2010, 2014, 2018],
#       dtype='int64', name='anio')

# %%
equipos_nuevo.reset_index(inplace = True)

# %%
equipos_nuevo.rename(columns = {'index': 'anio'}, inplace=True)

# %%
equipos_nuevo
# Out:
#     anio  Argentina  Brasil  Colombia  Ecuador  Uruguay
# 0   1930       16.0     4.0       NaN      NaN     15.0
# 1   1938        NaN     9.0       NaN      NaN      NaN
# 2   1950        NaN    21.0       NaN      NaN     15.0
# 3   1954        NaN     8.0       NaN      NaN     14.0
# 4   1958        3.0     6.0       NaN      NaN      NaN
# 5   1962        1.0    14.0       NaN      NaN      2.0
# 6   1966        4.0     2.0       NaN      NaN      2.0
# 7   1970        NaN     8.0       NaN      NaN      3.0
# 8   1974        7.0     1.0       NaN      NaN      1.0
# 9   1978       12.0     4.0       NaN      NaN      NaN
# 10  1982        7.0    10.0       NaN      NaN      NaN
# 11  1986       13.0     8.0       NaN      NaN      1.0
# 12  1990        3.0     4.0       NaN      NaN      0.0
# 13  1994        6.0    10.0       1.0      NaN      NaN
# 14  1998       11.0    17.0       1.0      NaN      NaN
# 15  2002        1.0     9.0       NaN      1.0      1.0
# 16  2006       10.0     6.0       NaN      3.0      NaN
# 17  2010        8.0     8.0       NaN      NaN     10.0
# 18  2014        5.0     9.0       7.0      0.0      3.0
# 19  2018        1.0     6.0       4.0      NaN      6.0

# %%
equipos_nuevo.dtypes
# Out:
# anio           int64
# Argentina    float64
# Brasil       float64
# Colombia     float64
# Ecuador      float64
# Uruguay      float64
# dtype: object

# %% [markdown]
# # a. Gráfico 1 deberá ser un gráfico en el que los datos de los países comparados aparezcan en el mismo cuadro.

# %%
fig = plt.figure()
fig.set_size_inches(14, 4, forward=True)
n = len(equipos_nuevo.index)
x = np.arange(n)
width = 0.35
plt.bar(x + width, equipos_nuevo.Brasil, width=width, label='Brasil', color='violet')
plt.bar(x, equipos_nuevo.Argentina, width=width, label='Argentina', color='orange')
plt.bar(x, equipos_nuevo.Uruguay, width=width, label='Uruguay', color='blue')
plt.bar(x, equipos_nuevo.Colombia, width=width, label='Colombia', color='turquoise')
plt.bar(x + width, equipos_nuevo.Ecuador, width=width, label='Ecuador', color='yellow')
plt.xticks(x + width, equipos_nuevo.anio)
plt.legend(loc='best')
#Ahora etiquetamos los ejes y le damos Titulo del grafico
plt.title('Número de Goles de los Países de América del Sur como 1er equipo en Mundiales')
plt.xlabel('Año')
plt.ylabel('Número de Goles')
#Podemos guardar la figura en un archivo
plt.savefig('Goles_de_5_países_1er_equipo_de_America_Sur.png')

# %% [markdown]
# # b. Gráfico 2 deberá ser un gráfico en el que los datos de cada país aparezca en un subgráfico diferente.

# %%
#Inicializamos una figura
fig = plt.figure()
fig.set_size_inches(15, 4, forward=True)
#Le damos un título
plt.title('Comparación de goles de cada país de América del Sur como 1er equipo en los diferentes mundiales de fútbol')
#Agregamos un eje (2 filas, 2 columnas, primer eje)
eje = fig.add_subplot(1, 5, 1)
#Graficamos los datos de Ecuador en el primer eje
equipos_nuevo.plot(x = 'anio', y = 'Ecuador', ax = eje, ls = "-.", color="red")

#Agregamos un segundo eje (2 filas, 2 columnas, segundo eje)
eje2 = fig.add_subplot(1, 5, 2, sharey = eje)
#Graficamos los datos de Argentina en el segundo eje
equipos_nuevo.plot(x = 'anio', y = 'Argentina', ax = eje2, ls = "-.", color="orange")

#Agregamos un tercer eje (2 filas, 2 columnas, segundo eje)
eje3 = fig.add_subplot(1, 5, 3, sharey = eje)
#Graficamos los datos de Brasil en el segundo eje
equipos_nuevo.plot(x = 'anio', y = 'Brasil', ax = eje3, ls = "-.", color="fuchsia")

#Agregamos un cuarto eje (2 filas, 2 columnas, segundo eje)
eje4 = fig.add_subplot(1, 5, 4, sharey = eje)
#Graficamos los datos de Colombia en el segundo eje
equipos_nuevo.plot(x = 'anio', y = 'Colombia', ax = eje4, ls = "-.", color="blue")

#Agregamos un quinto eje (2 filas, 2 columnas, segundo eje)
eje5 = fig.add_subplot(1, 5, 5, sharey = eje)
#Graficamos los datos de Uruguay en el segundo eje
equipos_nuevo.plot(x = 'anio', y = 'Uruguay', ax = eje5, ls = "-.", color="green")

#Agregamos etiquetas a los ejes
eje.set_xlabel('Año')
eje2.set_xlabel('Año')
eje3.set_xlabel('Año')
eje4.set_xlabel('Año')
eje5.set_xlabel('Año')
eje.set_ylabel('Número de Goles')
#Guardamos la imagen
plt.savefig('subgraficos_paises_en_la_copa_mundial.png')
